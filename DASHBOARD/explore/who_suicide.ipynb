# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from ipywidgets import interact, widgets

# %% [markdown]
# # PREPARE DATA

# %%
data = pd.read_csv("../data/who_suicide_latest.csv")
data.head()
# Out:
#               IND_ID    IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 0  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2013
# 1  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 2  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2015
# 3  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
# 4  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               800           COUNTRY              PUBLISHED
# 1          YEAR               818           COUNTRY              PUBLISHED
# 2          YEAR               818           COUNTRY              PUBLISHED
# 3          YEAR               858           COUNTRY              PUBLISHED
# 4          YEAR               860           COUNTRY              PUBLISHED
#
#          IND_NAME GEO_NAME_SHORT DIM_SEX DIM_AGE  RATE_PER_100000_N  \
# ...

# %%
data.nunique()
# Out:
# IND_ID                       1
# IND_CODE                     1
# IND_UUID                     1
# IND_PER_CODE                 1
# DIM_TIME                    20
# DIM_TIME_TYPE                1
# DIM_GEO_CODE_M49           194
# DIM_GEO_CODE_TYPE            4
# DIM_PUBLISH_STATE_CODE       1
# IND_NAME                     1
# GEO_NAME_SHORT             194
# DIM_SEX                      3
# DIM_AGE                     12
# RATE_PER_100000_N         7307
# RATE_PER_100000_NL        4036
# RATE_PER_100000_NU        7231
# dtype: int64

# %%
data.shape
# Out:
# (17518, 16)

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)

# %%
Nigerian_suicide_cases = data[data["GEO_NAME_SHORT"] == "Nigeria"]
Nigerian_suicide_cases
# Out:
#                   IND_ID    IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 79     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2001
# 80     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2010
# 87     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 311    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 646    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2004
# 947    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2017
# 971    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2000
# 1075   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 1107   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2011
# 1205   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2017
# 1757   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2004
# 2081   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2012
# 2218   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2000
# ...

# %%
Nigerian_suicide_cases.isnull().sum()
# Out:
# IND_ID                     0
# IND_CODE                   0
# IND_UUID                   0
# IND_PER_CODE               0
# DIM_TIME                   0
# DIM_TIME_TYPE              0
# DIM_GEO_CODE_M49           0
# DIM_GEO_CODE_TYPE          0
# DIM_PUBLISH_STATE_CODE     0
# IND_NAME                   0
# GEO_NAME_SHORT             0
# DIM_SEX                    0
# DIM_AGE                    0
# RATE_PER_100000_N          0
# RATE_PER_100000_NL        33
# RATE_PER_100000_NU        33
# dtype: int64

# %%
len(Nigerian_suicide_cases)
Nigerian_suicide_cases.nunique()
# Out:
# IND_ID                     1
# IND_CODE                   1
# IND_UUID                   1
# IND_PER_CODE               1
# DIM_TIME                  20
# DIM_TIME_TYPE              1
# DIM_GEO_CODE_M49           1
# DIM_GEO_CODE_TYPE          1
# DIM_PUBLISH_STATE_CODE     1
# IND_NAME                   1
# GEO_NAME_SHORT             1
# DIM_SEX                    3
# DIM_AGE                   12
# RATE_PER_100000_N         91
# RATE_PER_100000_NL        52
# RATE_PER_100000_NU        57
# dtype: int64

# %%
Nigerian_suicide_cases.rename(columns={
    "DIM_TIME": "Suicide_Year",
    "DIM_SEX": "Gender",
    "RATE_PER_100000_N": "Suicide_Rate_N",
    "RATE_PER_100000_NL": "Lower_Rate_NL",
    "RATE_PER_100000_NU": "Upper_Rate_NU"
}, inplace=True)
# Out:
# /var/folders/dl/jhpsjpfn1_5dp95f954942k80000gn/T/ipykernel_46718/395664634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nigerian_suicide_cases.rename(columns={

# %%
Nigerian_suicide_cases["Suicide_Year"]
# Out:
# 79       2001
# 80       2010
# 87       2005
# 311      2019
# 646      2004
# 947      2017
# 971      2000
# 1075     2005
# 1107     2011
# 1205     2017
# 1757     2004
# 2081     2012
# 2218     2000
# 2414     2015
# 2415     2011
# 2569     2009
# 2846     2018
# 3097     2007
# 3225     2000
# 3649     2013
# 3813     2010
# 3918     2010
# 4084     2003
# 4156     2006
# 4351     2016
# 4433     2012
# 4542     2009
# 4695     2003
# 5465     2002
# 5720     2016
# 6030     2008
# 6038     2016
# 6045     2007
# 6125     2002
# 6227     2015
# 6641     2001
# 7223     2006
# 7815     2017
# 7850     2008
# 8158     2008
# 8457     2019
# 8725     2019
# 9017     2013
# 9157     2005
# 9310     2007
# 9314     2018
# 9665     2003
# 9776     2018
# 9801     2009
# 9802     2012
# 9910     2013
# 9929     2011
# 9930     2006
# 10029    2014
# 10286    2014
# 11269    2014
# 11354    2004
# 11366    2001
# 11512    2002
# 11545    2015
# 11782    2019
# 11806    2019
# ...

# %%
# How many times each suicide_year_value is appearing more than once
suicide_year_counts = Nigerian_suicide_cases["Suicide_Year"].value_counts()
suicide_year_counts
# Out:
# Suicide_Year
# 2019    36
# 2001     3
# 2018     3
# 2008     3
# 2002     3
# 2016     3
# 2006     3
# 2003     3
# 2013     3
# 2007     3
# 2009     3
# 2010     3
# 2015     3
# 2012     3
# 2011     3
# 2000     3
# 2017     3
# 2004     3
# 2005     3
# 2014     3
# Name: count, dtype: int64

# %%
year_2019 = Nigerian_suicide_cases[Nigerian_suicide_cases["Suicide_Year"] == 2019]
year_2019.head()
# Out:
#                   IND_ID    IND_CODE IND_UUID IND_PER_CODE  Suicide_Year  \
# 311    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2019
# 8457   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2019
# 8725   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2019
# 11782  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2019
# 11806  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2019
#
#       DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE  \
# 311            YEAR               566           COUNTRY
# 8457           YEAR               566           COUNTRY
# 8725           YEAR               566           COUNTRY
# 11782          YEAR               566           COUNTRY
# 11806          YEAR               566           COUNTRY
#
#       DIM_PUBLISH_STATE_CODE        IND_NAME GEO_NAME_SHORT  Gender DIM_AGE  \
# 311                PUBLISHED  Suicide deaths        Nigeria   TOTAL   TOTAL
# ...

# %%
Nigerian_suicide_cases[Nigerian_suicide_cases["Suicide_Year"] == 2000]
# Out:
#                  IND_ID    IND_CODE IND_UUID IND_PER_CODE  Suicide_Year  \
# 971   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2000
# 2218  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2000
# 3225  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2000
#
#      DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 971           YEAR               566           COUNTRY              PUBLISHED
# 2218          YEAR               566           COUNTRY              PUBLISHED
# 3225          YEAR               566           COUNTRY              PUBLISHED
#
#             IND_NAME GEO_NAME_SHORT  Gender DIM_AGE  Suicide_Rate_N  \
# 971   Suicide deaths        Nigeria  FEMALE   TOTAL            2.85
# 2218  Suicide deaths        Nigeria    MALE   TOTAL            6.81
# 3225  Suicide deaths        Nigeria   TOTAL   TOTAL            4.85
#
#       Lower_Rate_NL  Upper_Rate_NU
# 971            1.52         4.5000
# ...

# %%
years_below_2019 = Nigerian_suicide_cases[Nigerian_suicide_cases["Suicide_Year"] <= 2018]
years_below_2019
# Out:
#                   IND_ID    IND_CODE IND_UUID IND_PER_CODE  Suicide_Year  \
# 79     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2001
# 80     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2010
# 87     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2005
# 646    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2004
# 947    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2017
# 971    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2000
# 1075   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2005
# 1107   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2011
# 1205   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2017
# 1757   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2004
# 2081   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2012
# 2218   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE          2000
# ...

# %%
sorted(Nigerian_suicide_cases["Suicide_Year"].unique())
Nigerian_suicide_cases["Suicide_Year"].unique()
Nigerian_suicide_cases["Suicide_Year"].nunique()
# Out:
# 20

# %%
Nigerian_suicide_cases.to_csv("../data/nigerian_suicide_cases.csv")

# %% [markdown]
# ### SCALAR VALUES

# %%
#Average suicide rate for both genders from 2000-2019
suicide_rate_for_total_genders = Nigerian_suicide_cases[(Nigerian_suicide_cases["Gender"] == "TOTAL") & (Nigerian_suicide_cases["DIM_AGE"] == "TOTAL")]

#Loop and print suicide value for total gender for each year
for year in sorted(suicide_rate_for_total_genders["Suicide_Year"].unique()):
    suicide_rate = suicide_rate_for_total_genders[suicide_rate_for_total_genders["Suicide_Year"] == year]["Suicide_Rate_N"].values[0]
    print(f"Year: {year}, Suicide Rate: {suicide_rate}")

# Calculate average value from 2000-2019
Average_suicide_value = suicide_rate_for_total_genders["Suicide_Rate_N"].mean()
print(f"\nAverage Suicide Rate from (2000–2019): {Average_suicide_value:.2f}")
# Out:
# Year: 2000, Suicide Rate: 4.85
# Year: 2001, Suicide Rate: 4.93
# Year: 2002, Suicide Rate: 4.84
# Year: 2003, Suicide Rate: 4.79
# Year: 2004, Suicide Rate: 4.83
# Year: 2005, Suicide Rate: 4.77
# Year: 2006, Suicide Rate: 4.71
# Year: 2007, Suicide Rate: 4.72
# Year: 2008, Suicide Rate: 4.64
# Year: 2009, Suicide Rate: 4.51
# Year: 2010, Suicide Rate: 4.4
# Year: 2011, Suicide Rate: 4.35
# Year: 2012, Suicide Rate: 4.2
# Year: 2013, Suicide Rate: 4.05
# Year: 2014, Suicide Rate: 3.85
# Year: 2015, Suicide Rate: 3.69
# Year: 2016, Suicide Rate: 3.66
# Year: 2017, Suicide Rate: 3.58
# Year: 2018, Suicide Rate: 3.53
# Year: 2019, Suicide Rate: 3.49
#
# Average Suicide Rate from (2000–2019): 4.32

# %%
# Get National average suicide rate 2019
overall_rate = Nigerian_suicide_cases[(Nigerian_suicide_cases["DIM_AGE"] == "TOTAL") & (Nigerian_suicide_cases["Gender"] == "TOTAL")]
latest_year = overall_rate["Suicide_Year"].max()
latest_rate = overall_rate[overall_rate["Suicide_Year"] == latest_year]["Suicide_Rate_N"].values[0]
print(f"The National average suicide rate for the year {latest_year} is: {latest_rate}")
# Out:
# The National average suicide rate for the year 2019 is: 3.49

# %%
# Age group and gender with the most alarming (highest) suicide rate
row = Nigerian_suicide_cases.loc[Nigerian_suicide_cases["Suicide_Rate_N"].idxmax(), ["DIM_AGE", "Gender", "Suicide_Rate_N"]]
print(f"Age group: {row['DIM_AGE']}, Gender: {row['Gender']}, Rate: {row['Suicide_Rate_N']} for the year 2019")
# Out:
# Age group: Y_GE85, Gender: MALE, Rate: 330.86 for the year 2019

# %%
# Age group and Female gender suicide rate
female_row = year_2019[year_2019["Gender"] == "FEMALE"].loc[year_2019[year_2019["Gender"] == "FEMALE"]["Suicide_Rate_N"].idxmax(), ["DIM_AGE", "Suicide_Rate_N"]]
print(f"Female — Age group: {female_row['DIM_AGE']}, Rate: {female_row['Suicide_Rate_N']} for the year 2019")
# Out:
# Female — Age group: Y_GE85, Rate: 93.9 for the year 2019

# %%
len(overall_rate)
# Out:
# 20

# %%
# # Get National average suicide rate 2010
latest_rate = overall_rate[overall_rate["Suicide_Year"] == 2010]["Suicide_Rate_N"].values[0]
print(f"The National average suicide rate for the year {2010} is: {latest_rate}")
# Out:
# The National average suicide rate for the year 2010 is: 4.4

# %% [markdown]
# # Visualizations

# %%
# 3D scatter plot
fig = px.scatter_3d(
    Nigerian_suicide_cases,
    x="DIM_AGE",
    y="Suicide_Rate_N",
    z="Gender",  # Use Gender as the third axis (categorical)
    color="Gender",  # Color-code by gender
    title="Suicide Rate by Age and Gender in Nigeria (3D)",
    labels={"Suicide_Rate_N": "Suicide Rate (per 100k)", "Age": "Age (Years)"},
    hover_data={"DIM_AGE": True, "Gender": True, "Suicide_Rate_N": ":.2f"},
    symbol="Gender",  # Optional: Different symbols for genders
    opacity=0.8,
    height=600,
)

fig.update_layout(
    scene=dict(
        xaxis_title="DIM_AGE",
        yaxis_title="Suicide_Rate_N",
        zaxis_title="Gender",
    ),
    margin=dict(l=0, r=0, b=0, t=30),
)

# Show the plot
fig.show()

# %%
def update_plots(selected_gender):
    filtered_data = data if selected_gender == "All" else Nigerian_suicide_cases[Nigerian_suicide_cases["Gender"] == selected_gender]
    
    # Scatter plot
    scatter = px.scatter(
        filtered_data, 
        x="DIM_AGE", 
        y="Suicide_Rate_N", 
        color="Gender",
        title="Suicide Rate by Age and Gender"
    )
    
    # Bar chart
    bar = px.bar(
        filtered_data, 
        x="Gender", 
        y="Suicide_Rate_N", 
        title="Average Suicide Rate by Gender"
    )
    
    scatter.show()
    bar.show()

# Add a gender dropdown
interact(update_plots, selected_gender=widgets.Dropdown(options=["TOTAL", "MALE", "FEMALE"]))
# Out:
# interactive(children=(Dropdown(description='selected_gender', options=('TOTAL', 'MALE', 'FEMALE'), value='TOTA…
# <function __main__.update_plots(selected_gender)>

# %%
Nigerian_suicide_cases.groupby(["DIM_AGE", "Gender"])["Suicide_Rate_N"].mean().unstack().plot(kind="bar")
# Out:
# <Axes: xlabel='DIM_AGE'>

# %%
from ipywidgets import interact, widgets
from IPython.display import display

# %%
# Line plot to show suicide mortality rate for relevant years

# %%
male = Nigerian_suicide_cases[Nigerian_suicide_cases["Gender"] == "MALE"]
female = Nigerian_suicide_cases[Nigerian_suicide_cases["Gender"] == "FEMALE"]
total = Nigerian_suicide_cases[Nigerian_suicide_cases["Gender"] == "TOTAL"]

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=male,
    x="Suicide_Year", y="Suicide_Rate_N",
    marker="o", label="Male", color="#1f77b4"
)
sns.lineplot(
    data=female,
    x="Suicide_Year", y="Suicide_Rate_N",
    marker="o", label="Female", color="#ff7f0e"
)
sns.lineplot(
    data=total,
    x="Suicide_Year", y="Suicide_Rate_N",
    marker="o", label="Total", color="#2ca02c"
)
plt.fill_between(
    male["Suicide_Year"], male["Lower_Rate_NL"], male["Upper_Rate_NU"],
    alpha=0.2, color="#1f77b4"
)
plt.fill_between(
    female["Suicide_Year"], female["Lower_Rate_NL"], female["Upper_Rate_NU"],
    alpha=0.2, color="#ff7f0e"
)
plt.title("Suicide Mortality Rates in Nigeria (2000–2017)")
plt.xlabel("Year")
plt.ylabel("Rate per 100,000")
plt.ylim(0, 12)
plt.grid(alpha=0.3)
plt.legend()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
overall_rate = Nigerian_suicide_cases['Suicide_Rate_N'].mean()
print(f"Overall suicide rate (per 100,000): {overall_rate:.2f}")
# Out:
# Overall suicide rate (per 100,000): 13.36

# %%
Nigerian_suicide_cases['Suicide_Rate_N']
# Out:
# 79       False
# 80       False
# 87       False
# 311      False
# 646      False
#          ...
# 16755    False
# 16972    False
# 17082    False
# 17130    False
# 17251    False
# Name: Suicide_Rate_N, Length: 93, dtype: bool

# %%
# Bar chart to show which gender committed more suicide

# %%
plt.bar(Nigerian_suicide_cases['Gender'], Nigerian_suicide_cases['Suicide_Rate_N'])
plt.title('Count by Gender 2000 - 2019')
plt.xlabel('Gender')
plt.ylabel('Suicide Rate per 100,000 People')
plt.tight_layout()
plt.show()

# %%
# Analysis by Age Group
age_data = Nigerian_suicide_cases[Nigerian_suicide_cases["DIM_AGE"].notna()]

plt.figure(figsize=(12, 6))
sns.boxplot(
    x="DIM_AGE",
    y="Suicide_Rate_N",
    data=age_data,
    palette="Set2"
)
plt.title("Suicide Rates by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Rate per 100,000")
plt.xticks(rotation=45)
plt.show()

# %%
# Error Bar
Nigerian_suicide_cases = Nigerian_suicide_cases.sort_values('Suicide_Year')
lower_errors = Nigerian_suicide_cases['Suicide_Rate_N'] - Nigerian_suicide_cases['Lower_Rate_NL']
upper_errors = Nigerian_suicide_cases['Upper_Rate_NU'] - Nigerian_suicide_cases['Suicide_Rate_N']
error = [lower_errors, upper_errors]

# Create the error bar plot
plt.figure(figsize=(10, 6))
plt.errorbar(
    Nigerian_suicide_cases['Suicide_Year'],
    Nigerian_suicide_cases['Suicide_Rate_N'],
    yerr=error,
    fmt='o-',  # 'o' for marker, '-' for line
    ecolor='gray',
    capsize=4,
    label='Suicide Rate with Uncertainty'
)

# Labeling
plt.title('Suicide Rate in Nigeria (with Uncertainty)')
plt.xlabel('Suicide Year')
plt.ylabel('Suicide Rate per 100,000')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Nigerian_suicide_cases.groupby('Suicide_Year')['Suicide_Rate_N'].mean().plot(kind='line')
# Out:
# <Axes: xlabel='Suicide_Year'>
