# %%
import pandas as pd

# %%
# Load csv into data frames
df1_sui = pd.read_csv("../data/who_suicide_latest.csv")
df2_pov = pd.read_csv("../data/ndp_poverty2004_2010.csv")
df3_emp = pd.read_csv("../data/unemployed.csv")

# %% [markdown]
# #### Inspect Datasets

# %%
print("df1 type:", type(df1_sui))
print("df1 shape:", df1_sui.shape)
print()
print("df2 type:", type(df2_pov))
print("df2 shape:", df2_pov.shape)
print()
print("df3 type:", type(df3_emp))
print("df3 shape:", df3_emp.shape)
# Out:
# df1 type: <class 'pandas.core.frame.DataFrame'>
# df1 shape: (17518, 16)
#
# df2 type: <class 'pandas.core.frame.DataFrame'>
# df2 shape: (160, 5)
#
# df3 type: <class 'pandas.core.frame.DataFrame'>
# df3 shape: (4563, 6)

# %%
print("df1 info:", df1_sui.info())
print("df2 info:", df2_pov.info())
print("df3 info:", df3_emp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17518 entries, 0 to 17517
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IND_ID                  17518 non-null  object
#  1   IND_CODE                17518 non-null  object
#  2   IND_UUID                17518 non-null  object
#  3   IND_PER_CODE            17518 non-null  object
#  4   DIM_TIME                17518 non-null  int64
#  5   DIM_TIME_TYPE           17518 non-null  object
#  6   DIM_GEO_CODE_M49        17518 non-null  int64
#  7   DIM_GEO_CODE_TYPE       17518 non-null  object
#  8   DIM_PUBLISH_STATE_CODE  17518 non-null  object
#  9   IND_NAME                17518 non-null  object
#  10  GEO_NAME_SHORT          17518 non-null  object
#  11  DIM_SEX                 17518 non-null  object
#  12  DIM_AGE                 17518 non-null  object
#  13  RATE_PER_100000_N       17518 non-null  float64
# ...

# %%
df1_sui.head()
# Out:
#               IND_ID    IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 0  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2013
# 1  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 2  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2015
# 3  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
# 4  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               800           COUNTRY              PUBLISHED
# 1          YEAR               818           COUNTRY              PUBLISHED
# 2          YEAR               818           COUNTRY              PUBLISHED
# 3          YEAR               858           COUNTRY              PUBLISHED
# 4          YEAR               860           COUNTRY              PUBLISHED
#
#          IND_NAME GEO_NAME_SHORT DIM_SEX DIM_AGE  RATE_PER_100000_N  \
# ...

# %%
df2_pov.head(10)
# Out:
#       region                                          indicator  Unit  Date  \
# 0       Abia  Revised Absolute Poverty 2003/04 (Adult Equiva...   NaN  2004
# 1       Abia  Revised Absolute Poverty 2003/04 (Per Capita M...   NaN  2004
# 2       Abia  Revised Absolute Poverty 2009/10 (Per Capita M...   NaN  2010
# 3       Abia  Revised Absolute Poverty 2009/10 (Adult Equiva...   NaN  2010
# 4    Adamawa  Revised Absolute Poverty 2003/04 (Adult Equiva...   NaN  2004
# 5    Adamawa  Revised Absolute Poverty 2003/04 (Per Capita M...   NaN  2004
# 6    Adamawa  Revised Absolute Poverty 2009/10 (Per Capita M...   NaN  2010
# 7    Adamawa  Revised Absolute Poverty 2009/10 (Adult Equiva...   NaN  2010
# 8  Akwa Ibom  Revised Absolute Poverty 2003/04 (Adult Equiva...   NaN  2004
# 9  Akwa Ibom  Revised Absolute Poverty 2003/04 (Per Capita M...   NaN  2004
#
#    Value
# 0   27.4
# 1   40.9
# 2   50.2
# 3   30.4
# 4   64.2
# 5   76.6
# 6   77.8
# 7   64.5
# 8   38.2
# 9   56.8

# %%
df2_pov.isnull().sum()
# Out:
# region         0
# indicator      0
# Unit         160
# Date           0
# Value          0
# dtype: int64

# %%
#drop columns where all columns are NaN:
df2_pov.dropna(axis=1, how='all', inplace=True)

# %%
df2_pov
print("df2 shape:", df2_pov.shape)
# Out:
# df2 shape: (160, 4)

# %%
print("df2 type:", type(df2_pov))
print("df2 shape:", df2_pov.shape)
# Out:
# df2 type: <class 'pandas.core.frame.DataFrame'>
# df2 shape: (160, 4)

# %%
df2_pov.head()
# Out:
#     region                                          indicator  Date  Value
# 0     Abia  Revised Absolute Poverty 2003/04 (Adult Equiva...  2004   27.4
# 1     Abia  Revised Absolute Poverty 2003/04 (Per Capita M...  2004   40.9
# 2     Abia  Revised Absolute Poverty 2009/10 (Per Capita M...  2010   50.2
# 3     Abia  Revised Absolute Poverty 2009/10 (Adult Equiva...  2010   30.4
# 4  Adamawa  Revised Absolute Poverty 2003/04 (Adult Equiva...  2004   64.2

# %%
df2_pov["indicator"][1]
# Out:
# 'Revised Absolute Poverty 2003/04 (Per Capita Methodology)'

# %%
df3_emp.head(10)
# Out:
#    country                                          indicator       group  \
# 0  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 1  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 2  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 3  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 4  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 5  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 6  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 7  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 8  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
# 9  Nigeria  LABOUR FORCE POPULATION (employment age and de...  All Groups
#
#       Unit    Date         Value
# 0  Persons    2010  6.517063e+07
# 1  Persons    2011  6.725609e+07
# 2  Persons    2012  6.910578e+07
# ...

# %%
df1_sui.isnull().sum()
# Out:
# IND_ID                       0
# IND_CODE                     0
# IND_UUID                     0
# IND_PER_CODE                 0
# DIM_TIME                     0
# DIM_TIME_TYPE                0
# DIM_GEO_CODE_M49             0
# DIM_GEO_CODE_TYPE            0
# DIM_PUBLISH_STATE_CODE       0
# IND_NAME                     0
# GEO_NAME_SHORT               0
# DIM_SEX                      0
# DIM_AGE                      0
# RATE_PER_100000_N            0
# RATE_PER_100000_NL        5888
# RATE_PER_100000_NU        5888
# dtype: int64

# %%
df2_pov.isnull().sum()
# Out:
# region         0
# indicator      0
# Unit         160
# Date           0
# Value          0
# dtype: int64

# %%
df3_emp.isnull().sum()
# Out:
# country      0
# indicator    0
# group        0
# Unit         0
# Date         0
# Value        0
# dtype: int64

# %%
df1_sui.nunique()
# Out:
# IND_ID                       1
# IND_CODE                     1
# IND_UUID                     1
# IND_PER_CODE                 1
# DIM_TIME                    20
# DIM_TIME_TYPE                1
# DIM_GEO_CODE_M49           194
# DIM_GEO_CODE_TYPE            4
# DIM_PUBLISH_STATE_CODE       1
# IND_NAME                     1
# GEO_NAME_SHORT             194
# DIM_SEX                      3
# DIM_AGE                     12
# RATE_PER_100000_N         7307
# RATE_PER_100000_NL        4036
# RATE_PER_100000_NU        7231
# dtype: int64

# %%
df2_pov.nunique()
# Out:
# region        40
# indicator      4
# Unit           0
# Date           2
# Value        143
# dtype: int64

# %%
df3_emp.nunique()
# Out:
# country         1
# indicator      17
# group          24
# Unit            3
# Date           25
# Value        4361
# dtype: int64

# %% [markdown]
# ## DATA WRANGLING

# %%
#extract Nigerian suicide data from WHO
df1_9jasui = df1_sui[df1_sui["GEO_NAME_SHORT"] == "Nigeria"]
df1_9jasui
# Out:
#                   IND_ID    IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 79     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2001
# 80     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2010
# 87     16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 311    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 646    16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2004
# ...                  ...         ...      ...          ...       ...
# 16755  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 16972  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 17082  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 17130  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 17251  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
#
#       DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE  \
# 79             YEAR               566           COUNTRY
# ...

# %%
#reset index
df1_9jasui.reset_index(drop=True, inplace=True)

# %%
#rename relevant columns for each datasets
